# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('Unemployment in India.csv')  # Replace with your dataset file path

# %%
# Check the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural
# Region                                      28
# ...

# %%
# Calculate summary statistics
print(data[' Estimated Labour Participation Rate (%)'].describe())
# Out:
# count    740.000000
# mean      42.630122
# std        8.111094
# min       13.330000
# 25%       38.062500
# 50%       41.160000
# 75%       45.505000
# max       72.570000
# Name:  Estimated Labour Participation Rate (%), dtype: float64

# %%
# Convert the ' Date' column to a datetime type with dayfirst=True
data[' Date'] = pd.to_datetime(data[' Date'], dayfirst=True)

# %%
# Convert the 'Date' column to a datetime type
data['Date'] = pd.to_datetime(data[' Date'])

# Visualize unemployment rate trends over time in India
plt.figure(figsize=(12, 6))
plt.plot(data[' Date'], data[' Estimated Unemployment Rate (%)'])
plt.title('Estimated Unemployment Rate in India Over Time')
plt.xlabel(' Date')
plt.ylabel('Unemployment Rate (%)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate summary statistics
print(data[' Estimated Unemployment Rate (%)'].describe())
# Out:
# count    740.000000
# mean      11.787946
# std       10.721298
# min        0.000000
# 25%        4.657500
# 50%        8.350000
# 75%       15.887500
# max       76.740000
# Name:  Estimated Unemployment Rate (%), dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np  # Add this import statement

# Load your dataset here (assuming you have already loaded it)

# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Visualize the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
